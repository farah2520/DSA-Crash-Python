# %%
# trees- rooted, acyclic, directed, not disconnected, each node has 1 parent
# binary tree- 2 children
# height of a balances binary tree is floor(log n)

# height- edges on longest path from the node to a leaf, height of root node (start from 0)

# max depth= height
