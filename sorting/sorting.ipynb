# %% [markdown]
# **BUBBLE SORT**

# %%
# Time-> o(n**2)
# space->o(1)

def bubble(arr):
  for i in range(len(arr)-1):
    for j in range(len(arr)-1-i):       # upto i coz ech iteration the larget value go and sits at the correct position
      if arr[j]>arr[j+1]:
        arr[j],arr[j+1]=arr[j+1],arr[j]
  return arr


bubble([1,2,3,4,0])
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# **INSERTION SORT**

# %%
# Time-> o(n**2)
# space->o(1)
# stable alogo, if 2 nos are same the first one will be at the first inex

def insertion(arr):
    for i in range(1, len(arr)):
        key = arr[i]              # current element
        j = i - 1
        while j >= 0 and arr[j] > key:   # shift larger elements to the right
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key            # insert key in correct position
    return arr

print(insertion([1, 12, 3, 4, 0]))
# Out:
# [0, 1, 3, 4, 12]

# %% [markdown]
# **SELECTION SORT**

# %%
# Time-> o(n**2)
# space->o(1)

def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        # Assume the first element of the unsorted part is the minimum
        min_index = i

        # Find the actual minimum in the unsorted part
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j

        # Swap the found minimum with the first unsorted element
        arr[i], arr[min_index] = arr[min_index], arr[i]

    return arr



print(selection_sort([1, 12, 3, 4, 0]))
# Out:
# [0, 1, 3, 4, 12]

# %% [markdown]
# **MERGE SORT**

# %%
# divide and conquer algo

# time- o(n log n)
# space-> o(n)

def merge_sorted_array(arr1, arr2):
  merged= []
  i,j=0,0
  while i<len(arr1) and j<len(arr2):
    if arr1[i]<=arr2[j]:
      merged.append(arr1[i])
      i+=1
    else:
      merged.append(arr2[j])
      j+=1


  while i<len(arr1):
    merged.append(arr1[i])
    i+=1
  while j<len(arr2):
    merged.append(arr2[j])
    j+=1
  return merged


def merge_sort(array):
  if len(array) <= 1:
        return array

  middle = len(array) // 2
  left_side = merge_sort(array[:middle])
  right_side = merge_sort(array[middle:])

  return merge_sorted_array(left_side, right_side)

# %% [markdown]
# **QUICK SORT**

# %%
# unstable- quick, selection, heap
