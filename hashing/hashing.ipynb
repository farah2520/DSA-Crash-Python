# %%
# hashtable- dict

# key-> hash func-> integer (between 0 and 5)

# collisions- same index has multiple values
# solve of collision- linked list in index, has values that point back to its key

# access val from hash table- O(1)
# insert- O(1)
# delete- O(1)
# search for key- O(1)
# search for value- o(n)
